# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
documents=[
    "Machine learning is a subset of artificial intelligence",
    "Deep learning uses neural networks with multiple layers",
    "Python is a programming language popular for data science",
    "India won the cricket world cup in 2011",
    "AI models can understand and generate human language"
]

# %%
from langchain_openai import OpenAIEmbeddings

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# %%
vector = embeddings.embed_documents(documents)

# %%
len(vector[0])
# Out:
# 1536

# %% [markdown]
# ## Store Vector Embeddings in Vector DB

# %%
from langchain_chroma import Chroma

# %%
vector_store = Chroma.from_texts(
    texts=documents,
    embedding=embeddings,
    persist_directory="./vector_db"
)

# %%
query ="Data Science"
result =vector_store.similarity_search(query=query, k=2)
result
# Out:
# [Document(id='341120bb-1b79-4e10-9d30-e2b17ca821d1', metadata={}, page_content='Python is a programming language popular for data science'),
#  Document(id='74e488a8-8d51-497b-aa40-a8338a1ded36', metadata={}, page_content='Python is a programming language popular for data science')]
