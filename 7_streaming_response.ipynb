# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

# %%
llm=ChatOpenAI(model="gpt-4",streaming=True)

# %%
question="can you explain me gen ai?"

# %%
response=llm.stream(question)
for chunk in response:
    print(chunk.content,end="")
# Out:
# Gen AI refers to the concept of artificial intelligence that is capable of general intelligence, similar to human intelligence. This means that instead of being highly specialized to perform a single or few tasks like the majority of AI today, Gen AI systems would ideally have the ability to understand, learn, adapt to new tasks, and solve problems they've never encountered before, all without human intervention.
#
# As of now, this is a goal rather than a reality. Currently, most artificial intelligence platforms are considered "narrow AI" because they are designed for specific tasks, such as voice recognition or image analysis. Developing a general AI or artificial general intelligence (AGI) that has the versatility and adaptability of human intelligence is an ongoing challenge and a subject of intensive research worldwide.

# %%
from langchain_groq import ChatGroq

# %%
llm=ChatGroq(model="openai/gpt-oss-120b",streaming=True)

# %%
question="can you explain me gen ai?"
response=llm.stream(question)
for chunk in response:
    print(chunk.content,end="")
# Out:
# ## Generative AI — A Beginner‑Friendly Overview
#
# ### 1. What *is* generative AI?
# Generative AI (Gen‑AI) refers to a class of artificial‑intelligence systems that **create new content** rather than just analyzing or classifying existing data.
# Typical outputs include:
#
# | Modality | Example of What It Can Generate |
# |----------|---------------------------------|
# | **Text** | Articles, poems, code, chat replies |
# | **Images** | Photorealistic pictures, art styles, design mock‑ups |
# | **Audio** | Speech, music, sound effects |
# | **Video** | Short clips, animation, deep‑fake footage |
# | **3‑D / Other** | CAD models, molecule structures, game levels |
#
# In short, if a machine can **produce something that didn’t exist before**, it’s likely using generative AI techniques.
#
# ---
#
# ### 2. How does it work? (High‑level)
#
# 1. **Training Data**
#    - Large collections of examples (e.g., billions of words, millions of images) are fed to the model.
#    - The data is usually cleaned, tokenized (converted to numbers), and sometimes labeled.
#
# 2. **Model Architecture**
#    - Most modern Gen‑AI uses **deep neural networks**.
#    - The dominant architecture today is the **Transformer**, introduced in 2017 (Vaswani et al.).
#    - Variants include:
#      - **Large Language Models (LLMs)** – e.g., GPT‑4, LLaMA, Claude.
#      - **Diffusion Models** – e.g., Stable Diffusion, DALL‑E 2 (for images).
#      - **GANs (Generative Adversarial Networks)** – earlier work for realistic images.
#      - **VAE (Variational Auto‑Encoders)** – used for many multimodal tasks.
#
# 3. **Learning Objective**
#    - **Self‑supervised**: the model predicts missing parts of the data (e.g., next word, masked token, noisy pixel).
#    - By minimizing prediction error, the network learns statistical patterns that let it **sample** new data later.
#
# 4. **Inference (Generation)**
#    - **Prompt**: you give the model a short instruction or seed (text, a sketch, a melody).
#    - **Sampling**: the model draws from its learned probability distribution to produce the next piece of content, step‑by‑step.
#    - Techniques like **temperature**, **top‑k / top‑p** sampling, or **classifier‑free guidance** control creativity vs. fidelity.
#
# 5. **Fine‑tuning & Alignment**
#    - After pre‑training on massive data, models are often **fine‑tuned** on a narrower domain (e.g., legal text) or **aligned** with human preferences using Reinforcement Learning from Human Feedback (RLHF).
#
# ---
#
# ### 3. Key Terminology (Quick Glossary)
#
# | Term | Meaning |
# |------|---------|
# | **Prompt** | The initial text/image/etc. that tells the model what to generate. |
# | **Token** | The smallest unit the model processes (word piece, character, pixel patch). |
# | **Temperature** | Controls randomness; higher = more creative, lower = more deterministic. |
# | **Top‑k / Top‑p (nucleus) sampling** | Limits the set of possible next tokens to the most probable ones. |
# | **RLHF** | Reinforcement Learning from Human Feedback; used to make outputs safer and more useful. |
# | **Parameter** | A weight in the neural network; modern LLMs have billions‑to‑trillions of them. |
# | **Diffusion** | A process that starts from random noise and iteratively denoises it to create an image. |
# | **Hallucination** | When the model generates plausible‑looking but factually incorrect information. |
#
# ---
#
# ### 4. Popular Generative AI Systems (as of 2024)
#
# | Domain | Notable Model(s) | Main Strength |
# |--------|------------------|---------------|
# | **Text** | GPT‑4, Claude 3, LLaMA‑2, Gemini | Long‑form reasoning, code generation, multilingual ability |
# | **Images** | Stable Diffusion, DALL‑E 3, Midjourney, Adobe Firefly | Photorealism, style control, high resolution |
# | **Audio** | Whisper (transcription), AudioLM, MusicLM | Speech‑to‑text, music generation, voice cloning |
# | **Video** | Sora (OpenAI), Phenaki, Runway Gen‑2 | Short clips, animation from text |
# | **Multimodal** | Gemini (Google), GPT‑4‑V, LLaVA | Text + image + audio in a single model |
# | **Code** | GitHub Copilot (based on OpenAI Codex), Tabnine | Autocompletion, whole‑function generation |
#
# ---
#
# ### 5. Real‑World Applications
#
# | Sector | Use‑Case | Example |
# |--------|----------|---------|
# | **Content Creation** | Blog posts, marketing copy, ad creatives | A marketer prompts “Write a 300‑word blog about sustainable travel” |
# | **Design & Art** | Concept art, UI mock‑ups, product visualizations | A product team generates 20 logo variations in seconds |
# | **Software Development** | Code suggestions, bug fixing, documentation | Copilot writes a function to parse CSV files |
# | **Healthcare** | Synthetic medical images for training, drug‑molecule design | Diffusion model creates labeled MRI scans for AI training |
# | **Education** | Personalized tutoring, question generation, language practice | A student asks “Explain photosynthesis in simple terms” |
# | **Gaming** | Procedural level generation, NPC dialogue | A game engine creates new quests on the fly |
# | **Enterprise** | Summarizing reports, drafting contracts, data extraction | An analyst gets a one‑page summary of a 200‑page PDF |
#
# ---
#
# ### 6. Benefits & Why It Matters
#
# | Benefit | What It Enables |
# |---------|-----------------|
# | **Speed** | Content that used to take hours/days can be produced in seconds. |
# | **Scale** | One model can serve millions of users simultaneously. |
# | **Creativity Amplification** | Humans can iterate faster, exploring ideas they might never think of. |
# | **Accessibility** | Non‑experts can generate high‑quality media (e.g., a small business creating ad graphics). |
# | **Cost Reduction** | Less reliance on expensive human labor for repetitive creative tasks. |
#
# ---
#
# ### 7. Challenges & Risks
#
# | Issue | Description |
# |-------|-------------|
# | **Hallucinations** | Model may output plausible‑sounding but false information—dangerous for factual tasks. |
# | **Bias & Fairness** | Training data reflects societal biases; outputs can perpetuate stereotypes. |
# | **Intellectual‑Property** | Generated images may resemble copyrighted works; legal frameworks are still evolving. |
# | **Misuse** | Deep‑fakes, disinformation, spam, and automated phishing can be powered by Gen‑AI. |
# | **Compute & Energy** | Training large models consumes significant electricity and specialized hardware. |
# | **Alignment** | Ensuring the model’s objectives match human values is an ongoing research area (RLHF, constitutional AI). |
#
# Mitigation strategies include: prompt engineering, post‑generation fact‑checking, watermarking, usage policies, and responsible AI governance.
#
# ---
#
# ### 8. Getting Started (If You Want to Try It)
#
# 1. **Free Web Interfaces**
#    - **ChatGPT**, **Claude**, **Gemini** (Google) – great for text.
#    - **Stable Diffusion** (via DreamStudio, Hugging Face Spaces) – generate images.
#
# 2. **Open‑Source Models**
#    - **LLaMA‑2**, **Mistral**, **Phi‑3** (text) – run locally on a decent GPU.
#    - **Stable Diffusion** (image) – install via `conda`/`pip` and run on a consumer GPU.
#
# 3. **APIs**
#    - OpenAI, Anthropic, Google Cloud, Azure AI – pay‑as‑you‑go for production‑grade reliability.
#
# 4. **Learning Resources**
#    - **Coursera / edX**: “Generative AI” specializations.
#    - **Fast.ai**: practical deep‑learning courses.
#    - **Hugging Face**: model hub, tutorials, and a vibrant community.
#
# 5. **Safety First**
#    - Review the provider’s usage policy.
#    - Add human-in‑the‑loop checks for critical outputs (e.g., medical advice, legal text).
#
# ---
#
# ### 9. The Future Outlook (2025‑2030)
#
# | Trend | What It Means |
# |-------|----------------|
# | **Multimodal “Foundation” Models** | One model that can understand and generate text, images, audio, and video together. |
# | **Parameter‑Efficient Fine‑Tuning** | Techniques like LoRA, adapters, and prompt‑tuning let small teams adapt huge models without massive compute. |
# | **Real‑Time Interaction** | Latency dropping below 100 ms, enabling live‑chat, gaming, and AR/VR experiences. |
# | **Regulatory Frameworks** | Governments worldwide are drafting laws on AI transparency, watermarking, and liability. |
# | **Energy‑Efficient Training** | New hardware (e.g., AI‑optimized chips) and algorithmic tricks reduce carbon footprint. |
# | **Human‑AI Co‑Creation** | Workflows where AI suggests, humans edit, and AI learns from the edits—tight feedback loops. |
#
# ---
#
# ### 10. TL;DR Summary
#
# - **Generative AI** = AI that **creates** new content (text, images, audio, video, etc.).
# - It learns patterns from massive datasets using **deep neural networks**—most commonly **Transformer**‑based models.
# - You interact via **prompts**, and the model **samples** from learned probabilities to generate output.
# - Applications span **creative work, software, healthcare, education, gaming, and business automation**.
# - Benefits: speed, scale, creativity, accessibility.
# - Risks: hallucinations, bias, misuse, IP concerns, high compute cost.
# - You can try it today through free web tools, open‑source models, or paid APIs—just keep safety and ethics in mind.
#
# Feel free to ask follow‑up questions—whether you want a deeper dive into the math, a code example, or guidance on building your own generative‑AI pipeline!
