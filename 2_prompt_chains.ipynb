# %%
from langchain_openai import ChatOpenAI

# %%
llm=ChatOpenAI(model="gpt-4")

# %%
prompts=[
    {"role":"system","content":"You are Python developer"},
    {"role":"user","content":"Difference between map and filter"}
]
res=llm.invoke(prompts)
print(res.content)
# Out:
# `map` and `filter` are two built-in functions in Python that operate on lists (and other iterable objects).
#
# `map`:
#
# The `map` function applies a given function to each item of an iterable (such as a list, dictionary, set, tuple etc.) and returns a list of the results.
#
# Syntax: map(function, iterable)
#
# It's used when you want to perform the same operation on every element in the iterable.
#
# Example:
# ```python
# def square(n):
#      return n**2
#
# numbers = [1, 2, 3, 4]
# result = map(square, numbers)
# print(list(result)) # Output: [1, 4, 9, 16]
# ```
# In this example, the `map` function applies the `square` function to every item in the `numbers` list.
#
# `filter`:
#
# The `filter` function constructs an iterator from elements of an iterable for which a function returns true.
#
# Syntax: filter(function, iterable)
#
# `filter` is used when you want to filter out elements from an iterable.
#
# Example:
# ```python
# def is_even(n):
#      return n % 2 == 0
#
# ...

# %%
prompts=[
    {"role":"system","content":"You are javascript developer"},
    {"role":"user","content":"Difference between map and filter"}
]
res=llm.invoke(prompts)
print(res.content)
# Out:
# `map` and `filter` are both higher-order functions that process arrays, but they perform different tasks:
#
# 1. `.map()` in JavaScript:
#
# The `map()` method creates a new array with the results of calling a provided function on every element in the array on which it is called. This method calls the provided function once for each element in an array, in order, and constructs a new array from the results. It does not modify the original array.
#
# For example: If you want to get a new array by doubling all numbers in an original array, you can utilize the `map()` function.
#
# ```js
# let numbers = [1, 2, 3];
# let doubledNumbers = numbers.map(number => number * 2);
# console.log(doubledNumbers);  // [2, 4, 6]
# ```
#
# 2. `.filter()` in JavaScript:
#
# ...

# %%
prompts=[
    {"role":"system","content":"You are translator and translate input in Hindi"},
    {"role":"user","content":"I love singing"}
]
res=llm.invoke(prompts)
print(res.content)
# Out:
# मुझे गाना गाना पसंद है।

# %% [markdown]
# ### Prompt Templates- Dynamic Prompts

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm=ChatOpenAI(model="gpt-4")
out=StrOutputParser

# %% [markdown]
# #### My self chain node

# %%
def transform_case(result:str):
    return result.upper()

# %%
prompts=ChatPromptTemplate.from_messages([
    {"role":"system","content":"You are translator and translate input {language} in english"},
    {"role":"user","content":"{query}"},
])

# %%
# final_prompts =prompts.format_messages(language="Hinglish",
#                                        query="I love Python and Javascript")
# res=llm.invoke(final_prompts)
# print(res.content)

# %% [markdown]
# ### Chains- Runnable

# %%
# res=llm.invoke(prompts.invoke({"language":"hindi","query":"i love you"}))
# res.content

# %%
chains = prompts | llm | StrOutputParser() | transform_case

# %%
chains
# Out:
# ChatPromptTemplate(input_variables=['language', 'query'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['language'], input_types={}, partial_variables={}, template='You are translator and translate input {language} in english'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['query'], input_types={}, partial_variables={}, template='{query}'), additional_kwargs={})])
# ...

# %%
res=chains.invoke({"language":"english","query":"i love langchain"})
print(res)
# Out:
# I LOVE LANGCHAIN.
