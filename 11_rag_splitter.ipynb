# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text="Artificial intelligence combines algorithms, data, and computing resources to solve tasks that traditionally required human judgment."

# %%
splitter=RecursiveCharacterTextSplitter(chunk_size=50,chunk_overlap=20)

# %%
chunks=splitter.split_text(text)

# %%
chunks
# Out:
# ['Artificial intelligence combines algorithms, data,',
#  'algorithms, data, and computing resources to',
#  'resources to solve tasks that traditionally',
#  'that traditionally required human judgment.']

# %% [markdown]
# ## Document Text Loader

# %%
from langchain_community.document_loaders import TextLoader,PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# C:\Users\Nidhi Mehta\AppData\Local\Temp\ipykernel_7732\1418189172.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader,PyPDFLoader

# %%
loader = TextLoader("../data/speech.txt")
text=loader.load()

# %%
pdfloader=PyPDFLoader("../data/medical_report.pdf")
pdfs=pdfloader.load()
len(pdfs)
# Out:
# 41

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)

# %%
text_chunks=splitter.split_documents(text)
len(text_chunks)
# Out:
# 602

# %%
# text_chunks

# %%
pdf_chunks=splitter.split_documents(pdfs)
len(pdf_chunks)
# Out:
# 201
