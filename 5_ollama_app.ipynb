# %%
from langchain_ollama import ChatOllama

# %%
llm=ChatOllama(model="gemma3:1b")

# %%
res=llm.invoke("Hello, I am nidhi")
res.content
# Out:
# "Hello Nidhi! It's nice to meet you. How can I help you today?"
