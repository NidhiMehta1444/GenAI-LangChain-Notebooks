# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Text Document Loader

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader("../data/speech.txt")
texts=loader.load()
len(texts)

oneDoc=texts[0]
print(oneDoc.page_content)
# Out:
# THE PRACTICAL FUTURE OF DATA, AI, AND DIGITAL TRANSFORMATION
#
# Long-form sample document for Retrieval-Augmented Generation testing
#
# This document contains intentionally large amounts of structured and unstructured text. It is designed for testing document loading, chunking, embedding, retrieval, metadata handling, and question answering in a RAG pipeline.
#
# Section 1: Artificial Intelligence
#
# Artificial intelligence combines algorithms, data, and computing resources to solve tasks that traditionally required human judgment.
#
# Organizations adopting artificial intelligence need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 1: Generative AI
#
# Generative AI systems create text, code, images, summaries, and other content from instructions and contextual information.
#
# Organizations adopting generative ai need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 1: Retrieval-Augmented Generation
#
# Retrieval-Augmented Generation connects a language model with an external knowledge base so answers can be grounded in retrieved documents.
#
# Organizations adopting retrieval-augmented generation need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 1: Data Engineering
#
# Data engineering focuses on collecting, transforming, validating, storing, and serving reliable data for analytics and machine learning.
#
# Organizations adopting data engineering need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 1: Data Quality
#
# Data quality involves completeness, accuracy, consistency, timeliness, uniqueness, and validity of information used by an organization.
#
# Organizations adopting data quality need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 1: Cloud Computing
#
# Cloud platforms provide scalable computing, storage, databases, networking, monitoring, and managed services.
#
# Organizations adopting cloud computing need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 1: Cybersecurity
#
# Cybersecurity protects applications, infrastructure, identities, and information against unauthorized access and malicious activity.
#
# Organizations adopting cybersecurity need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 1: Responsible AI
#
# Responsible AI emphasizes transparency, privacy, security, fairness, explainability, human oversight, and appropriate governance.
#
# Organizations adopting responsible ai need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 1: Machine Learning
#
# Machine learning allows systems to learn patterns from historical examples and use those patterns to make predictions or classifications.
#
# Organizations adopting machine learning need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 1: Analytics
#
# Business analytics converts raw data into measurements and insights that can support operational and strategic decisions.
#
# Organizations adopting analytics need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 2: Artificial Intelligence
#
# Artificial intelligence combines algorithms, data, and computing resources to solve tasks that traditionally required human judgment.
#
# Organizations adopting artificial intelligence need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 2: Generative AI
#
# Generative AI systems create text, code, images, summaries, and other content from instructions and contextual information.
#
# Organizations adopting generative ai need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 2: Retrieval-Augmented Generation
#
# Retrieval-Augmented Generation connects a language model with an external knowledge base so answers can be grounded in retrieved documents.
#
# Organizations adopting retrieval-augmented generation need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 2: Data Engineering
#
# Data engineering focuses on collecting, transforming, validating, storing, and serving reliable data for analytics and machine learning.
#
# Organizations adopting data engineering need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 2: Data Quality
#
# Data quality involves completeness, accuracy, consistency, timeliness, uniqueness, and validity of information used by an organization.
#
# Organizations adopting data quality need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 2: Cloud Computing
#
# Cloud platforms provide scalable computing, storage, databases, networking, monitoring, and managed services.
#
# Organizations adopting cloud computing need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 2: Cybersecurity
#
# Cybersecurity protects applications, infrastructure, identities, and information against unauthorized access and malicious activity.
#
# Organizations adopting cybersecurity need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 2: Responsible AI
#
# Responsible AI emphasizes transparency, privacy, security, fairness, explainability, human oversight, and appropriate governance.
#
# Organizations adopting responsible ai need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 2: Machine Learning
#
# Machine learning allows systems to learn patterns from historical examples and use those patterns to make predictions or classifications.
#
# Organizations adopting machine learning need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 2: Analytics
#
# Business analytics converts raw data into measurements and insights that can support operational and strategic decisions.
#
# Organizations adopting analytics need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 3: Artificial Intelligence
#
# Artificial intelligence combines algorithms, data, and computing resources to solve tasks that traditionally required human judgment.
#
# Organizations adopting artificial intelligence need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 3: Generative AI
#
# Generative AI systems create text, code, images, summaries, and other content from instructions and contextual information.
#
# Organizations adopting generative ai need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 3: Retrieval-Augmented Generation
#
# Retrieval-Augmented Generation connects a language model with an external knowledge base so answers can be grounded in retrieved documents.
#
# Organizations adopting retrieval-augmented generation need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 3: Data Engineering
#
# ...
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 10: Data Engineering
#
# Data engineering focuses on collecting, transforming, validating, storing, and serving reliable data for analytics and machine learning.
#
# Organizations adopting data engineering need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 10: Data Quality
#
# Data quality involves completeness, accuracy, consistency, timeliness, uniqueness, and validity of information used by an organization.
#
# Organizations adopting data quality need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 10: Cloud Computing
#
# Cloud platforms provide scalable computing, storage, databases, networking, monitoring, and managed services.
#
# Organizations adopting cloud computing need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 10: Cybersecurity
#
# Cybersecurity protects applications, infrastructure, identities, and information against unauthorized access and malicious activity.
#
# Organizations adopting cybersecurity need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 10: Responsible AI
#
# Responsible AI emphasizes transparency, privacy, security, fairness, explainability, human oversight, and appropriate governance.
#
# Organizations adopting responsible ai need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 10: Machine Learning
#
# Machine learning allows systems to learn patterns from historical examples and use those patterns to make predictions or classifications.
#
# Organizations adopting machine learning need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.
#
#
# Section 10: Analytics
#
# Business analytics converts raw data into measurements and insights that can support operational and strategic decisions.
#
# Organizations adopting analytics need clear objectives, reliable data, measurable outcomes, and appropriate controls. A successful implementation usually begins with understanding the business problem before selecting a technology. Teams should identify the source systems, define the expected output, document assumptions, and establish a process for reviewing results.
#
# A useful operating model separates experimentation from production. During experimentation, teams can test alternative approaches, compare results, identify failure cases, and collect feedback. Before production deployment, the solution should be evaluated for reliability, security, performance, maintainability, and cost.
#
# Documentation is equally important. Technical documentation should describe data sources, transformations, dependencies, configuration, interfaces, monitoring, and recovery procedures. Business documentation should explain what the system does, what its outputs mean, and where human review is required.
#
# Another important consideration is measurement. Teams should define metrics before implementation so that improvements can be evaluated objectively. Depending on the use case, measurements may include accuracy, precision, recall, latency, availability, adoption, cost per transaction, error rate, or user satisfaction.
#
# As systems become more complex, organizations also need governance. Access should be controlled according to roles, sensitive information should be protected, and changes should be traceable. Periodic reviews can identify outdated assumptions, changing data distributions, and new operational risks.
#
# The central principle is that technology should support a clearly understood business objective. A technically impressive system may still provide limited value if it does not solve the intended problem, cannot be maintained, or produces results that users cannot trust.

# %% [markdown]
# ### PDF Document Loader

# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader("../data/medical_report.pdf")
docs=loader.load()
len(docs)
# Out:
# 41

# %%
oneDoc=docs[0]
print(oneDoc.page_content)
# Out:
# Comprehensive Sample Medical Records Collection
# Fictional training document: All patient records, names, values, dates, diagnoses, and observations in this PDF
# are synthetic and created only for RAG/document-processing demonstrations. They are not real medical records.
# Patient Record 10001
# This synthetic record represents visit number 5 for patient PAT-10001. The patient is 62 years old and attended
# the clinic for a routine health evaluation. The information below is intended to provide varied searchable content
# for document retrieval.
# Clinical Field
# Recorded Value
# Patient ID
# PAT-10001
# Age
# 62
# Visit Type
# preventive care visit
# Blood Pressure
# 112/65 mmHg
# Heart Rate
# 75 bpm
# Temperature
# 97.7 °F
# Hemoglobin
# 12.1 g/dL
# Fasting Glucose
# 84 mg/dL
# Total Cholesterol
# 231 mg/dL
# BMI
# 28.1
# Assessment
# maintain regular health reviews
# Clinical note: The sample record includes blood pressure of 112/65 mmHg, heart rate of 75 bpm, temperature of
# 97.7 °F, hemoglobin of 12.1 g/dL, fasting glucose of 84 mg/dL, cholesterol of 231 mg/dL, and BMI of 28.1. This
# paragraph intentionally repeats key fields in natural language to provide additional content for semantic retrieval
# and question-answering experiments.
# Patient Record 10002
# This synthetic record represents visit number 6 for patient PAT-10002. The patient is 24 years old and attended
# the clinic for a preventive care visit. The information below is intended to provide varied searchable content for
# document retrieval.
# Clinical Field
# Recorded Value
# Patient ID
# PAT-10002
# Age
# 24
# Visit Type
# general health screening
# Blood Pressure
# 106/67 mmHg
# Heart Rate
# 71 bpm
# Temperature
# 97.6 °F
# Hemoglobin
# 14.1 g/dL
# Fasting Glucose
# 113 mg/dL
# Total Cholesterol
# 170 mg/dL
# BMI
# 27.8
# Assessment
# continue preventive care

# %% [markdown]
# ### CSV File Loader

# %%
from langchain_community.document_loaders import CSVLoader
loader=CSVLoader("../data/employee_records.csv")
docs=loader.load()
len(docs)
docs[:5]
# Out:
# [Document(metadata={'source': '../data/employee_records.csv', 'row': 0}, page_content='employee_id: 10001\nname: Rohan Gupta\ndepartment: Data Engineering\njob_title: ETL Developer\nlocation: Gurugram\nannual_salary_inr: 1009003\nyears_experience: 2.1\nage: 23\nstatus: Active\nperformance_rating: Needs Improvement\nprojects_completed: 6\njoining_year: 2021\nmanager_name: Maya Sharma\nemployment_type: Full Time\nprimary_skills: Python, PySpark, AWS'),
#  Document(metadata={'source': '../data/employee_records.csv', 'row': 1}, page_content='employee_id: 10002\nname: Manish Rao\ndepartment: Operations\njob_title: Process Analyst\nlocation: Bengaluru\nannual_salary_inr: 453503\nyears_experience: 13.6\nage: 26\nstatus: On Leave\nperformance_rating: Meets Expectations\nprojects_completed: 2\njoining_year: 2011\nmanager_name: Rahul Iyer\nemployment_type: Full Time\nprimary_skills: SQL, Power BI, Excel'),
#  Document(metadata={'source': '../data/employee_records.csv', 'row': 2}, page_content='employee_id: 10003\nname: Simran Desai\ndepartment: Data Engineering\njob_title: Data Engineer\nlocation: Bengaluru\nannual_salary_inr: 2106900\nyears_experience: 13.6\nage: 39\nstatus: Active\nperformance_rating: Needs Improvement\nprojects_completed: 8\njoining_year: 2019\nmanager_name: Pooja Khan\nemployment_type: Full Time\nprimary_skills: Machine Learning, Python, Scikit-learn'),
#  Document(metadata={'source': '../data/employee_records.csv', 'row': 3}, page_content='employee_id: 10004\nname: Kabir Khan\ndepartment: Operations\njob_title: Program Coordinator\nlocation: Ahmedabad\nannual_salary_inr: 1789569\nyears_experience: 8.1\nage: 41\nstatus: Active\nperformance_rating: Meets Expectations\nprojects_completed: 7\njoining_year: 2026\nmanager_name: Varun Mehta\nemployment_type: Full Time\nprimary_skills: Excel, SQL, Tableau'),
#  Document(metadata={'source': '../data/employee_records.csv', 'row': 4}, page_content='employee_id: 10005\nname: Maya Gupta\ndepartment: Cybersecurity\njob_title: Security Analyst\nlocation: Bengaluru\nannual_salary_inr: 1972171\nyears_experience: 12.4\nage: 52\nstatus: Notice Period\nperformance_rating: Good\nprojects_completed: 3\njoining_year: 2021\nmanager_name: Rahul Nair\nemployment_type: Full Time\nprimary_skills: SQL, Power BI, Excel')]

# %% [markdown]
# ### Web Page Loader

# %%
from langchain_community.document_loaders import WebBaseLoader
loader=WebBaseLoader(web_path="https://cloud.google.com/gemini-enterprise")
docs=loader.load()

# %%
# docs[0].metadata

# %% [markdown]
# ## Wikipedia Loader

# %%
from langchain_community.document_loaders import WikipediaLoader
loader=WikipediaLoader(query="Gen AI",load_max_docs=2)
docs=loader.load()

# %%
docs[0].page_content
# Out:
# 'Generative artificial intelligence (GenAI) is a subfield of artificial intelligence (AI) that uses generative models to generate text, images, videos, audio, computer code or other forms of digital data. These models learn the underlying patterns and structures of their training data, and use them to generate new data in response to input, which often takes the form of natural language prompts.\nThe prevalence of generative AI tools has increased significantly since the AI boom of the 2020s, typically thought to have begun in November 2022 with the release of ChatGPT. This boom was made possible by improvements in deep neural networks, particularly large language models (LLMs), which are based on the transformer architecture. Generative AI applications include chatbots such as ChatGPT, Claude, Microsoft Copilot, DeepSeek, Doubao, Google Gemini, Grok, Kimi and Qwen; text-to-image models such as DALL-E, Firefly, Stable Diffusion, and Midjourney; and text-to-video models such as Veo, LTX and Sora.\nCompanies in a variety of sectors have used generative AI, including those in software development, healthcare, finance, entertainment, sales and marketing, writing, and product design.  \nGenerative AI has been used for cybercrime, and to deceive and manipulate people through fake news and deepfakes. Generative AI models have been trained on copyrighted works without the rightholders\' permission. Many generative AI systems are reliant on large-scale data centers, whose environmental impacts include electronic waste, consumption of fresh water for cooling, and high energy consumption that is estimated to be growing steadily.\n\n\n== History ==\n\n\n=== Early history ===\nThe origins of algorithmically generated media can be traced to the development of the Markov chain, which has been used to model natural language since the early 20th century. Russian mathematician Andrey Markov introduced the concept in 1906, including an analysis of vowel and consonant patterns in Eugene Onegin. Once trained on a text corpus, a Markov chain can generate probabilistic text.\nBy the early 1970s, artists began using computers to extend generative techniques beyond Markov models. Harold Cohen developed and exhibited works produced by AARON, a pioneering computer program designed to autonomously create paintings.\nThe terms generative AI planning or generative planning were used in the 1980s and 1990s to refer to AI planning systems, especially computer-aided process planning, used to generate sequences of actions to reach a specified goal. Generative AI planning systems used symbolic AI methods such as state space search and constraint satisfaction and were a "relatively mature" technology by the early 1990s. They were used to generate crisis action plans for military use, process plans for manufacturing and decision plans such as in prototype autonomous spacecraft.\n\n\n=== Generative neural networks (since the late 2000s) ===\n\nMachine learning uses both discriminative models and generative models to predict or generate data. Beginning in the late 2000s and early 2010s, advances in deep learning led to major improvements in image classification, speech recognition, and natural language processing. Neural networks in this period were typically trained as discriminative models due to the relative difficulty of training generative models.\nIn 2014, the introduction of models such as the variational autoencoder (VAE) and generative adversarial network (GAN) enabled effective deep generative modeling of complex data such as images. In 2017, the paper "Attention Is All You Need" proposed that transformer architecture could enable further advances in generative modeling compared to earlier long short-term memory (LSTM) networks. This led to the development of generative pre-trained transformer (GPT) models, beginning with GPT-1 in 2018.\n\n\n=== Generative AI adoption ===\n\nIn March 2020, the release of 15.ai, a free web application created by an anonymo ...
